# %%
import pandas as pd

# %%
import csv

with open('neurostroke_data.csv', encoding='ISO-8859-1') as infile:
    reader = csv.reader(infile)
    data = [row for row in reader]

with open('output.csv', mode='w', newline='', encoding='utf-8') as outfile:
    writer = csv.writer(outfile)
    writer.writerows(data)

# %%
df = pd.read_csv('output.csv')
# Out:
# C:\Users\44786\AppData\Local\Temp\ipykernel_2360\1993316442.py:1: DtypeWarning: Columns (6,9,10,31,92) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('output.csv')

# %%
df
# Out:
#        Hospital_Number  Delay_in_Hours_at_Randomization  \
# 0                    1                               17
# 1                    1                               10
# 2                    1                               43
# 3                    1                                6
# 4                    4                               20
# ...                ...                              ...
# 19430              255                               42
# 19431              255                               47
# 19432              341                               21
# 19433              255                               40
# 19434              255                               15
#
#       Conscious_State_at_Randomization  Gender  Age_in_Years  \
# 0                               Drowsy    Male            69
# 1                          Fully Alert    Male            76
# 2                          Fully Alert  Female            71
# ...

# %%
# Convert True to 1 and False to 0 for all columns
df = df.replace({True: 1, False: 0})

# %%
df
# Out:
#        Hospital_Number  Delay_in_Hours_at_Randomization  \
# 0                    1                               17
# 1                    1                               10
# 2                    1                               43
# 3                    1                                6
# 4                    4                               20
# ...                ...                              ...
# 19430              255                               42
# 19431              255                               47
# 19432              341                               21
# 19433              255                               40
# 19434              255                               15
#
#       Conscious_State_at_Randomization  Gender  Age_in_Years  \
# 0                               Drowsy    Male            69
# 1                          Fully Alert    Male            76
# 2                          Fully Alert  Female            71
# ...

# %%
# iterating the columns
for col in df.columns:
  print(col)
# Out:
# Hospital_Number
# Delay_in_Hours_at_Randomization
# Conscious_State_at_Randomization
# Gender
# Age_in_Years
# Is_Symptoms_Noted_on_Waking
# Is_Atrial_Fibrillation_Coded
# Is_CT_Before_Randomization
# Is_Infarct_Visible_on_CT
# Is_Heparin_Before_Randomization
# Is_Aspirin_Before_Randomization
# Systolic_Blood_Pressure_at_Randomization
# Face_Deficit
# Arm_Hand_Deficit
# Leg_Foot_Deficit
# Dysphasia
# Hemianopia
# Visuospatial_Disorder
# Cerebellar_Signs
# Deficit_Others
# Stroke_Subtype
# Date_of_Randomization_Oxford
# Local_Time_in_Hours
# Local_Time_in_Minutes
# Local_Day_of_Week
# Is_Trial_Aspirin_Allocated
# Trial_Heparin_Allocated
# Aspirin_Given_For_14_Days
# Discharged_On_Long_Term_Aspirin
# Low_Dose_Heparin_Given_For_14_Days
# Medium_Dose_Heparin_Given_For_14_Days
# Is_Medium_Dose_Heparin_Given_For_14_Days_in_Pilot
# Time_In_Days_On_Trial_Treatment
# Non_Trial_Subcutaneous_Heparin
# Non_Trial_Intravenous_Heparin
# Non_Trial_Antiplatelet_Drug
# Anticoagulants_Others
# ...

# %%
df['Not_A_Stroke'].unique()
# Out:
# array(['no', 'yes', nan, 'unknown'], dtype=object)

# %%
df['Not_A_Stroke'].isna().sum()
# Out:
# 26

# %%
df1 = df.dropna(subset=['Not_A_Stroke'])

# %%
df1['Not_A_Stroke'].unique()
# Out:
# array(['no', 'yes', 'unknown'], dtype=object)

# %%
df1['Not_A_Stroke'].isna().sum()
# Out:
# 0

# %%
countnull=df1.isnull().sum()

# %%
columns=df1.columns

# %%
for i in range(len(countnull)):
  print(columns[i],'-',countnull[i])
# Out:
# Hospital_Number - 0
# Delay_in_Hours_at_Randomization - 0
# Conscious_State_at_Randomization - 0
# Gender - 0
# Age_in_Years - 0
# Is_Symptoms_Noted_on_Waking - 0
# Is_Atrial_Fibrillation_Coded - 984
# Is_CT_Before_Randomization - 0
# Is_Infarct_Visible_on_CT - 0
# Is_Heparin_Before_Randomization - 344
# Is_Aspirin_Before_Randomization - 984
# Systolic_Blood_Pressure_at_Randomization - 0
# Face_Deficit - 0
# Arm_Hand_Deficit - 0
# Leg_Foot_Deficit - 0
# Dysphasia - 0
# Hemianopia - 0
# Visuospatial_Disorder - 0
# Cerebellar_Signs - 0
# Deficit_Others - 0
# Stroke_Subtype - 0
# Date_of_Randomization_Oxford - 0
# Local_Time_in_Hours - 348
# Local_Time_in_Minutes - 348
# Local_Day_of_Week - 0
# Is_Trial_Aspirin_Allocated - 0
# Trial_Heparin_Allocated - 0
# Aspirin_Given_For_14_Days - 8
# Discharged_On_Long_Term_Aspirin - 133
# Low_Dose_Heparin_Given_For_14_Days - 8
# Medium_Dose_Heparin_Given_For_14_Days - 992
# Is_Medium_Dose_Heparin_Given_For_14_Days_in_Pilot - 18425
# ...

# %%
pd.options.display.max_rows = 4000
df.isnull().sum().sort_values(ascending=False)
# Out:
# Days_Elapsed_From_Randomization_to_Date_of_Last_Contact                19377
# Days_Elapsed_From_Randomization_to_Recurrent_Haemorrhagic_Stroke       19338
# Days_Elapsed_From_Randomization_to_Pulmonary_Embolism                  19310
# Comment_on_Major_Non_Cerebral_Haemorrhage                              19290
# Days_Elapsed_From_Randomization_to_Major_Non_Cerebral_Haemorrhage      19286
# Comment_on_Death_Within_14_Days                                        19267
# Days_Elapsed_From_Randomization_to_Unknown_Type                        19175
# Days_Elapsed_From_Randomization_to_Recurrent_Ischaemic_Stroke          19022
# Comment_on_Final_Diagnosis_of_Initial_Event                            19008
# Days_Elapsed_From_Randomization_to_Side_Effects                        18802
# Comment_on_Side_Effect                                                 18797
# Comment_on_Death_at_Six_Month_Follow_Up                                18651
# ...

# %%
df1 = df1.dropna(axis='columns',thresh=100)

# %%
df1
# Out:
#        Hospital_Number  Delay_in_Hours_at_Randomization  \
# 0                    1                               17
# 1                    1                               10
# 2                    1                               43
# 3                    1                                6
# 4                    4                               20
# ...                ...                              ...
# 19430              255                               42
# 19431              255                               47
# 19432              341                               21
# 19433              255                               40
# 19434              255                               15
#
#       Conscious_State_at_Randomization  Gender  Age_in_Years  \
# 0                               Drowsy    Male            69
# 1                          Fully Alert    Male            76
# 2                          Fully Alert  Female            71
# ...

# %%
pct_null = df1.isnull().sum() / len(df1)
missing_features = pct_null[pct_null > 0.1].index
df1.drop(missing_features, axis=1, inplace=True)

# %%
pct_null
# Out:
# Hospital_Number                                                        0.000000
# Delay_in_Hours_at_Randomization                                        0.000000
# Conscious_State_at_Randomization                                       0.000000
# Gender                                                                 0.000000
# Age_in_Years                                                           0.000000
# Is_Symptoms_Noted_on_Waking                                            0.000000
# Is_Atrial_Fibrillation_Coded                                           0.050698
# Is_CT_Before_Randomization                                             0.000000
# Is_Infarct_Visible_on_CT                                               0.000000
# Is_Heparin_Before_Randomization                                        0.017724
# Is_Aspirin_Before_Randomization                                        0.050698
# Systolic_Blood_Pressure_at_Randomization                               0.000000
# ...

# %%
df1
# Out:
#        Hospital_Number  Delay_in_Hours_at_Randomization  \
# 0                    1                               17
# 1                    1                               10
# 2                    1                               43
# 3                    1                                6
# 4                    4                               20
# ...                ...                              ...
# 19430              255                               42
# 19431              255                               47
# 19432              341                               21
# 19433              255                               40
# 19434              255                               15
#
#       Conscious_State_at_Randomization  Gender  Age_in_Years  \
# 0                               Drowsy    Male            69
# 1                          Fully Alert    Male            76
# 2                          Fully Alert  Female            71
# ...

# %%
df1.isnull().sum().sort_values(ascending=False)
# Out:
# Unknown_Type                                                           992
# Medium_Dose_Heparin_Given_For_14_Days                                  992
# Carotid_Surgery                                                        991
# Is_Aspirin_Before_Randomization                                        984
# Is_Atrial_Fibrillation_Coded                                           984
# Days_Elapsed_From_Randomization_to_Date_Discharge_Form_Completed       457
# Local_Time_in_Hours                                                    348
# Local_Time_in_Minutes                                                  348
# Is_Heparin_Before_Randomization                                        344
# Thrombolysis                                                           301
# Non_Trial_Intravenous_Heparin                                          291
# Non_Trial_Subcutaneous_Heparin                                         291
# ...

# %%
for column in df1.columns:
    df1[column].fillna(df1[column].mode()[0], inplace=True)

# %%
df1.isnull().sum().sort_values(ascending=False)
# Out:
# Hospital_Number                                                        0
# Days_Elapsed_From_Randomization_to_Date_Discharge_Form_Received        0
# Time_of_Death_in_Days                                                  0
# Is_Death_Indicator                                                     0
# Is_Compliant_for_Heparin                                               0
# Is_Compliant_for_Aspirin                                               0
# Days_Elapsed_From_Randomization_to_Date_Discharge_Form_Completed       0
# Country_Code                                                           0
# Abbreviated_Country_Code                                               0
# Days_Elapsed_From_Randomization_to_Date_at_Six_Month_Follow_Up_Done    0
# Dead_at_Six_Month_Follow_Up                                            0
# Predicted_Probability_of_Death_at_Six_Month                            0
# Dead_on_Discharge_Within_14_Days                                       0
# ...

# %%
df1
# Out:
#        Hospital_Number  Delay_in_Hours_at_Randomization  \
# 0                    1                               17
# 1                    1                               10
# 2                    1                               43
# 3                    1                                6
# 4                    4                               20
# ...                ...                              ...
# 19430              255                               42
# 19431              255                               47
# 19432              341                               21
# 19433              255                               40
# 19434              255                               15
#
#       Conscious_State_at_Randomization  Gender  Age_in_Years  \
# 0                               Drowsy    Male            69
# 1                          Fully Alert    Male            76
# 2                          Fully Alert  Female            71
# ...

# %%
df1.drop('Hospital_Number',axis=1,inplace =True)

# %%
df1
# Out:
#        Delay_in_Hours_at_Randomization Conscious_State_at_Randomization  \
# 0                                   17                           Drowsy
# 1                                   10                      Fully Alert
# 2                                   43                      Fully Alert
# 3                                    6                      Fully Alert
# 4                                   20                      Fully Alert
# ...                                ...                              ...
# 19430                               42                      Fully Alert
# 19431                               47                      Fully Alert
# 19432                               21                      Fully Alert
# 19433                               40                           Drowsy
# 19434                               15                      Fully Alert
#
#        Gender  Age_in_Years  Is_Symptoms_Noted_on_Waking  \
# ...

# %%
categorical_columns=df1.select_dtypes(include=['object']).columns.tolist()

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
def Encoder(df):
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df
print(Encoder(df))
# Out:
# Error encoding Is_Dead_or_Alive_at_14_Days
#        Hospital_Number  Delay_in_Hours_at_Randomization  \
# 0                    1                               17
# 1                    1                               10
# 2                    1                               43
# 3                    1                                6
# 4                    4                               20
# ...                ...                              ...
# 19430              255                               42
# 19431              255                               47
# 19432              341                               21
# 19433              255                               40
# 19434              255                               15
#
#        Conscious_State_at_Randomization  Gender  Age_in_Years  \
# 0                                     0       1            69
# 1                                     1       1            76
# ...

# %%
df = Encoder(df1)
# Out:
# Error encoding Is_Dead_or_Alive_at_14_Days

# %%
df
# Out:
#        Delay_in_Hours_at_Randomization  Conscious_State_at_Randomization  \
# 0                                   17                                 0
# 1                                   10                                 1
# 2                                   43                                 1
# 3                                    6                                 1
# 4                                   20                                 1
# ...                                ...                               ...
# 19430                               42                                 1
# 19431                               47                                 1
# 19432                               21                                 1
# 19433                               40                                 0
# 19434                               15                                 1
#
#        Gender  Age_in_Years  Is_Symptoms_Noted_on_Waking  \
# ...

# %%
df['Not_A_Stroke']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19430    0
# 19431    0
# 19432    0
# 19433    0
# 19434    0
# Name: Not_A_Stroke, Length: 19409, dtype: int32

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming 'df' is your DataFrame with mixed data types

# Step 1: Identify non-numeric columns (if any)
non_numeric_cols = df.select_dtypes(exclude='number').columns

# Step 2: Convert non-numeric values to numeric (e.g., 'true' to 1, 'false' to 0)
# You can use 'replace' to map specific values to numeric equivalents
df[non_numeric_cols] = df[non_numeric_cols].replace({'true': 1, 'false': 0})

# Step 3: Convert the DataFrame to numeric (if any non-numeric values are still present)
df = df.apply(pd.to_numeric, errors='coerce')

# Step 4: Drop rows with NaN (if applicable)
# If you used 'pd.to_numeric' with 'coerce', non-convertible values will become NaN
# You can choose to drop rows with NaN if they are not relevant for your analysis
df.dropna(inplace=True)

# %%
from sklearn.preprocessing import StandardScaler
# Initialise the Scaler
scaler = StandardScaler()
# To scale data
scaler.fit(df)
sdf=scaler.transform(df)

# %%
sdf
# Out:
# array([[-0.25031363, -1.82252499,  0.93130409, ..., -0.03368651,
#         -0.09287903, -0.16771398],
#        [-0.81169297,  0.47161779,  0.93130409, ..., -0.03368651,
#         -0.09287903, -0.16771398],
#        [ 1.83480964,  0.47161779, -1.07376314, ..., -0.03368651,
#         -0.09287903, -0.16771398],
#        ...,
#        [ 0.07047457,  0.47161779,  0.93130409, ..., -0.03368651,
#         -0.09287903, -0.16771398],
#        [ 1.59421849, -1.82252499, -1.07376314, ..., -0.03368651,
#         -0.09287903, -0.16771398],
#        [-0.41070773,  0.47161779,  0.93130409, ..., -0.03368651,
#         -0.09287903, -0.16771398]])

# %%
df
# Out:
#        Delay_in_Hours_at_Randomization  Conscious_State_at_Randomization  \
# 0                                   17                                 0
# 1                                   10                                 1
# 2                                   43                                 1
# 3                                    6                                 1
# 4                                   20                                 1
# ...                                ...                               ...
# 19430                               42                                 1
# 19431                               47                                 1
# 19432                               21                                 1
# 19433                               40                                 0
# 19434                               15                                 1
#
#        Gender  Age_in_Years  Is_Symptoms_Noted_on_Waking  \
# ...

# %%
x=df.drop('Not_A_Stroke',axis=1)

# %%
y=df['Not_A_Stroke']

# %%
print(y.value_counts())
# Out:
# 0    18983
# 2      420
# 1        6
# Name: Not_A_Stroke, dtype: int64

# %%
y=y.replace(2,1)

# %%
print(y.value_counts())
# Out:
# 0    18983
# 1      426
# Name: Not_A_Stroke, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_rem, y_train, y_rem = train_test_split(x,y, train_size=0.7)
test_size = 0.5
X_valid, X_test, y_valid, y_test = train_test_split(X_rem,y_rem, test_size=0.5)

print(X_train.shape), print(y_train.shape)
print(X_valid.shape), print(y_valid.shape)
print(X_test.shape)
# Out:
# (13586, 85)
# (13586,)
# (2911, 85)
# (2911,)
# (2912, 85)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 2021)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
X_train
# Out:
#        Delay_in_Hours_at_Randomization  Conscious_State_at_Randomization  \
# 0                                   12                                 1
# 1                                   13                                 1
# 2                                   38                                 1
# 3                                   31                                 0
# 4                                   19                                 0
# ...                                ...                               ...
# 30373                                5                                 0
# 30374                                8                                 1
# 30375                                7                                 1
# 30376                               12                                 1
# 30377                                3                                 0
#
#        Gender  Age_in_Years  Is_Symptoms_Noted_on_Waking  \
# ...

# %%
y_train
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30373    1
# 30374    1
# 30375    1
# 30376    1
# 30377    1
# Name: Not_A_Stroke, Length: 30378, dtype: int32

# %%
print(y_train.value_counts())
# Out:
# 0    15189
# 1    15189
# Name: Not_A_Stroke, dtype: int64

# %%
import numpy as np
from xgboost import XGBClassifier
import time
from sklearn.metrics import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, SVR
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import *
from numpy import logspace
from joblib import load, dump
from sklearn.metrics import classification_report, confusion_matrix

# %%
# instantiate the model
xgb = XGBClassifier(learning_rate=0.4,max_depth=7)
#fit the model
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.4, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_valid_xgb = xgb.predict(X_valid)

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_valid, y_valid_xgb)
class_labels = ['No Stroke', 'Stroke']
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8,6 ))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Validation Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report
print("Classification Report for Validation Set:")
print(classification_report(y_valid, y_valid_xgb))
# Out:
# Classification Report for Validation Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2839
#            1       1.00      1.00      1.00        72
#
#     accuracy                           1.00      2911
#    macro avg       1.00      1.00      1.00      2911
# weighted avg       1.00      1.00      1.00      2911

# %%
#predicting the target value from the model for the samples
y_test_xgb = xgb.predict(X_test)

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_test_xgb)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Test Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)


## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report
print("Classification Report for Test Set:")
print(classification_report(y_test, y_test_xgb))
# Out:
# Classification Report for Test Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3794
#            1       0.98      1.00      0.99        88
#
#     accuracy                           1.00      3882
#    macro avg       0.99      1.00      0.99      3882
# weighted avg       1.00      1.00      1.00      3882

# %%
# Decision Tree model 
from sklearn.tree import DecisionTreeClassifier

# instantiate the model 
tree = DecisionTreeClassifier(max_depth = 5)
# fit the model 
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
y_valid_tree = tree.predict(X_valid)

# %%
#Generate the confusion matrix
cf_matrix = confusion_matrix(y_valid, y_valid_tree)

class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8,6 ))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Validation Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
print("Classification Report for Validation Set:")
print(classification_report(y_valid, y_valid_tree))
# Out:
# Classification Report for Validation Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2839
#            1       1.00      1.00      1.00        72
#
#     accuracy                           1.00      2911
#    macro avg       1.00      1.00      1.00      2911
# weighted avg       1.00      1.00      1.00      2911

# %%
#predicting the target value from the model for the samples
y_test_tree = tree.predict(X_test)
y_train_tree = tree.predict(X_train)

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_test_tree)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Test Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)


## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report
print("Classification Report for Test Set:")
print(classification_report(y_test, y_test_tree))
# Out:
# Classification Report for Test Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3794
#            1       0.98      1.00      0.99        88
#
#     accuracy                           1.00      3882
#    macro avg       0.99      1.00      0.99      3882
# weighted avg       1.00      1.00      1.00      3882

# %%
#checking the feature improtance in the model
plt.figure(figsize=(10,20))
n_features = X_train.shape[1]
plt.barh(range(n_features), tree.feature_importances_, align='center')
plt.yticks(np.arange(n_features), X_train.columns)
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.show()

# %%
# Random Forest model
from sklearn.ensemble import RandomForestClassifier

# instantiate the model
forest = RandomForestClassifier()

# fit the model 
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_valid_forest = forest.predict(X_valid)

# %%
cf_matrix = confusion_matrix(y_valid, y_valid_forest)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8,6 ))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Validation Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
print("Classification Report for Validation Set:")
print(classification_report(y_valid, y_valid_forest))
# Out:
# Classification Report for Validation Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2839
#            1       1.00      0.94      0.97        72
#
#     accuracy                           1.00      2911
#    macro avg       1.00      0.97      0.99      2911
# weighted avg       1.00      1.00      1.00      2911

# %%
#predicting the target value from the model for the samples
y_test_forest = forest.predict(X_test)
y_train_forest = forest.predict(X_train)

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_test_forest)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Test Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)


## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report
print("Classification Report for Test Set:")
print(classification_report(y_test, y_test_forest))
# Out:
# Classification Report for Test Set:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3794
#            1       1.00      0.67      0.80        88
#
#     accuracy                           0.99      3882
#    macro avg       1.00      0.84      0.90      3882
# weighted avg       0.99      0.99      0.99      3882

# %%
#Support vector machine model
from sklearn.svm import SVC

# instantiate the model
svm = SVC(kernel='linear', C=1.0, random_state=12)
#fit the model
svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=12)

# %%
y_valid_svm = svm.predict(X_valid)

# %%
#Generate the confusion matrix
cf_matrix = confusion_matrix(y_valid, y_valid_svm)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8,6 ))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Validation Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
print("Classification Report for Validation Set:")
print(classification_report(y_valid, y_valid_svm))
# Out:
# Classification Report for Validation Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2839
#            1       1.00      1.00      1.00        72
#
#     accuracy                           1.00      2911
#    macro avg       1.00      1.00      1.00      2911
# weighted avg       1.00      1.00      1.00      2911

# %%
y_test_svm = svm.predict(X_test)

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_test_svm)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Test Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)


## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report
print("Classification Report for Test Set:")
print(classification_report(y_test, y_test_svm))
# Out:
# Classification Report for Test Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3794
#            1       0.98      1.00      0.99        88
#
#     accuracy                           1.00      3882
#    macro avg       0.99      1.00      0.99      3882
# weighted avg       1.00      1.00      1.00      3882

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier




# Instantiate individual models (xgb, tree, forest, svm) before using them in the VotingClassifier
xgb = XGBClassifier(learning_rate=0.4, max_depth=7)
tree = DecisionTreeClassifier()
forest = RandomForestClassifier()
svm = SVC()

# Create the VotingClassifier
model = VotingClassifier(estimators=[('xgb', xgb), ('tree', tree), ('rf', forest), ('svm', svm)], voting='hard')

# Fit the VotingClassifier on the training data
model.fit(X_train, y_train)

# Evaluate the performance on the test set
test_score = model.score(X_test, y_test)
print("Test set accuracy:", test_score)

# Make predictions on the validation set
y_val = model.predict(X_valid)

# Evaluate the performance on the validation set
valid_score = model.score(X_valid, y_valid)
print("Validation set accuracy:", valid_score)
# Out:
# Test set accuracy: 0.997166409067491
# Validation set accuracy: 0.9993129508759876

# %%
cf_matrix = confusion_matrix(y_valid, y_val)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8,6 ))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Validation Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
print("Classification Report for Validation Set:")
print(classification_report(y_valid, y_val))
# Out:
# Classification Report for Validation Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2839
#            1       1.00      0.97      0.99        72
#
#     accuracy                           1.00      2911
#    macro avg       1.00      0.99      0.99      2911
# weighted avg       1.00      1.00      1.00      2911

# %%
y_test_v = model.predict(X_test)

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_test_v)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (Test Set)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)


## Display the visualization of the Confusion Matrix.
plt.show()

# %%
from sklearn.metrics import classification_report
print("Classification Report for Test Set:")
print(classification_report(y_test, y_test_v))
# Out:
# Classification Report for Test Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3794
#            1       0.99      0.89      0.93        88
#
#     accuracy                           1.00      3882
#    macro avg       0.99      0.94      0.97      3882
# weighted avg       1.00      1.00      1.00      3882

# %%
from keras import Sequential
from keras.layers import Dense,Dropout,Activation

# %%
#forming model
model=Sequential()

# %%
#building the model
model.add(Dense(units=128,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=64,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=32,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1,activation='softmax'))

# %%
#compiling
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
hist=model.fit(X_train,y_train,batch_size=64,epochs = 100)
# Out:
# Epoch 1/100
# 475/475 [==============================] - 1s 1ms/step - loss: 1.6071 - accuracy: 0.5000
# Epoch 2/100
# 475/475 [==============================] - 1s 1ms/step - loss: 0.7098 - accuracy: 0.5000
# Epoch 3/100
# 475/475 [==============================] - 1s 1ms/step - loss: 0.6728 - accuracy: 0.5000
# Epoch 4/100
# 475/475 [==============================] - 1s 1ms/step - loss: 0.5126 - accuracy: 0.5000
# Epoch 5/100
# 475/475 [==============================] - 1s 1ms/step - loss: 0.2643 - accuracy: 0.5000
# Epoch 6/100
# 475/475 [==============================] - 1s 1ms/step - loss: 0.1366 - accuracy: 0.5000
# Epoch 7/100
# 475/475 [==============================] - 1s 1ms/step - loss: 0.0850 - accuracy: 0.5000
# Epoch 8/100
# 475/475 [==============================] - 1s 1ms/step - loss: 0.0622 - accuracy: 0.5000
# Epoch 9/100
# 475/475 [==============================] - 1s 1ms/step - loss: 0.0422 - accuracy: 0.5000
# Epoch 10/100
# ...

# %%
pred=model.predict(X_test)
# Out:
# 122/122 [==============================] - 0s 766us/step

# %%
classes_x=np.argmax(pred,axis=1)

# %%
from sklearn.metrics import classification_report
print("Classification Report for ANN:")
print(classification_report(y_test, classes_x))
# Out:
# Classification Report for ANN:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3794
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.98      3882
#    macro avg       0.49      0.50      0.49      3882
# weighted avg       0.96      0.98      0.97      3882
# C:\Users\44786\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\44786\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, classes_x)
class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (ANN)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)


## Display the visualization of the Confusion Matrix.
plt.show()

# %%
print("MODEL_SUMMARY")
model.summary()
# Out:
# MODEL_SUMMARY
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               11008
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 21377 (83.50 KB)
# Trainable params: 21377 (83.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.layers import Dense, Dropout, Activation

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Activation

# %%
print(X_train.shape)  # Should be (number of samples, 85)
print(X_valid.shape)  # Should be (number of samples, 85)
print(X_test.shape)   # Should be (number of samples, 85)
# Out:
# (30378, 85)
# (2911, 85)
# (3882, 85)

# %%
from keras import layers, models
from keras.layers import Conv2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from keras.optimizers import Adam
from keras.regularizers import l2
model = models.Sequential()
model.add(Dense(11, input_dim=85, activation='relu', kernel_regularizer=l2(0.0001)))
model.add(Dropout(0.2))

    # Hidden layer: 22 neurons, relu activation, dropout=0.2
model.add(Dense(22, activation='relu', kernel_regularizer=l2(0.0001)))
model.add(Dropout(0.2))

    # Hidden layer: 10 neurons, relu activation, dropout=0.2, batch norm
model.add(Dense(10, activation='relu', kernel_regularizer=l2(0.0001)))
model.add(Dropout(0.2))
model.add(BatchNormalization())

    # Hidden layer: 10 neurons, relu activation, dropout=0.2, batch norm
model.add(Dense(10, activation='relu', kernel_regularizer=l2(0.0001)))
model.add(Dropout(0.2))
model.add(BatchNormalization())

    # Hidden layer: 10 neurons, relu activation, dropout=0.2, batch norm
model.add(Dense(10, activation='relu', kernel_regularizer=l2(0.0001)))
model.add(Dropout(0.2))
model.add(BatchNormalization())

    # Output layer: 1 neuron (regression output)
model.add(Dense(1, activation='relu'))
print(model.summary())

    # train the model
    # binary crossentropy, adam optimizer, learning rate=0.001, L2 regulatization
model.compile(optimizer=Adam(lr=0.001),
                  loss='binary_crossentropy',
                  metrics=['binary_accuracy'])
history = model.fit(X_train,
                        y_train,
                        epochs=50,
                        batch_size=5,
                        validation_data=(X_valid, y_val))

print('Performance: ', model.evaluate(X_test, y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 11)                946
#
#  dropout_3 (Dropout)         (None, 11)                0
#
#  dense_5 (Dense)             (None, 22)                264
#
#  dropout_4 (Dropout)         (None, 22)                0
#
#  dense_6 (Dense)             (None, 10)                230
#
#  dropout_5 (Dropout)         (None, 10)                0
#
#  batch_normalization (Batch  (None, 10)                40
#  Normalization)
#
#  dense_7 (Dense)             (None, 10)                110
#
#  dropout_6 (Dropout)         (None, 10)                0
#
#  batch_normalization_1 (Bat  (None, 10)                40
#  chNormalization)
#
#  dense_8 (Dense)             (None, 10)                110
#
#  dropout_7 (Dropout)         (None, 10)                0
#
#  batch_normalization_2 (Bat  (None, 10)                40
# ...

# %%
pred=model.predict(X_test)
# Out:
# 122/122 [==============================] - 0s 628us/step

# %%
from sklearn.metrics import classification_report
print("Classification Report for CNN:")
print(classification_report(y_test, classes_x))
# Out:
# Classification Report for CNN:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      3794
#            1       0.00      0.00      0.00        88
#
#     accuracy                           0.98      3882
#    macro avg       0.49      0.50      0.49      3882
# weighted avg       0.96      0.98      0.97      3882
# C:\Users\44786\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\44786\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, classes_x)

class_labels = ['No Stroke', 'Stroke']

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=1.2)
plt.figure(figsize=(8, 6))
ax = sns.heatmap(cf_matrix, annot=True, fmt="d", cmap='YlGnBu', cbar=False)

ax.set_title('Confusion Matrix for Neuro Stroke Prediction (CNN)\n')
ax.set_xlabel('\nPREDICTED LABEL')
ax.set_ylabel('TRUE LABEL\n')

ax.set_xticklabels(class_labels)
ax.set_yticklabels(class_labels)


## Display the visualization of the Confusion Matrix.
plt.show()
